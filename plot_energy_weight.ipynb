# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import seaborn as sns

# %%
data = pd.read_csv("./data/DataSetTrussStructure.csv").loc[:, ["N° image", "Energie", "Poids"]]

# %%
data
# Out:
#       N° image   Energie        Poids
# 0            1  0.025088  3901.671856
# 1            2  0.043002  3159.119087
# 2            3  0.021369  3575.895111
# 3            4  0.044654  3276.268680
# 4            5  0.036768  3173.978488
# ...        ...       ...          ...
# 1996      1997  0.021233  3352.060281
# 1997      1998  0.023403  3338.811195
# 1998      1999  0.020354  3456.720204
# 1999      2000  0.044875  3182.877027
# 2000      2001  0.038393  3197.261485
#
# [2001 rows x 3 columns]

# %%
sns.histplot(data["Energie"], bins=50, kde=True)
# Out:
# <Axes: xlabel='Energie', ylabel='Count'>

# %%
sns.histplot(data["Poids"], bins=50, kde=True)
# Out:
# <Axes: xlabel='Poids', ylabel='Count'>

# %%
sns.scatterplot(data.loc[:, ["Poids", "Energie"]])
# Out:
# <Axes: >
